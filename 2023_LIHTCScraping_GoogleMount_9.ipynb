# %% [markdown]
# <a href="https://colab.research.google.com/github/PratishCalPolyFinance/GrayScale/blob/main/2023_LIHTCScraping_GoogleMount_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**
#
# In this notebook, I scrape the 2023 9% LIHTC data from the main [website](https://https://www.treasurer.ca.gov/ctcac/2023/application.asp). Note that at the time of the code, CTCAC had not processed the 2nd round 9% applications yet. The first round 9% applications can be found [here](https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/index.asp).

# %% [markdown]
# # **Set up**
#
# It turns out that google colab is not set up for R programming; it works better for python programming. They have come up with two ways to code in [R](https://https://towardsdatascience.com/how-to-use-r-in-google-colab-b6e02d736497). The first way uses Python and the second way changes runtime server to R. The second way sucks and is not all that robust. For example, in the second way, **one cannot mount google drive,** which makes it pretty hard to share. Hence, I will use the first way.
#
#
# ---
#
#
# To run the first way, execute the next code line %load_ext rpy2.ipython

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# ---
#
# ## **Mount the Google Drive**
#
# Get the LIHTC Scraping folder and copy it inside the mydrive folder.
#
# This is crucial. This will need to be done everytime you run the code.

# %% [markdown]
# ---
#
# # **Code Flowchart**
#
# Once the google drive is mounted, then we are ready to use the files inside it to run the code. Basically, all the files are going to reside in google drive and we can call them using relative paths. The algorithm is as follows.
#
# 1.   Load all the relevant packages: package_load_00.text
# 2.   Get a list of the links for the all the excel files for the 9% applications
# 3.   Get a list of all the applications that got awarded. The information will be useful to create an "Awarded Flag"
# 4.   Load all the helper functions needed to extract information
# 5.   Scrape Application Worksheet
#
#
#
# ---

# %% [markdown]
# ## **Load Packages**
#
# Note that the process may take a few minutes the first time this is done.

# %%
# %%R
#
# source("/content/drive/MyDrive/LIHTC Scraping/Code/package_load_00.txt")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: pacman
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/pacman_0.5.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 274400 bytes (267 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %% [markdown]
# ## **Get hyperlinks of all the application excel files**
#
# The list will be saved in a variable called hyperlinks_2023_1_9. The second round can be

# %%
# %%R
#
# source("/content/drive/MyDrive/LIHTC Scraping/Code/9 percent/2023WebsiteLinkAggregatorFunc_01.R")
#
# head(hyperlinks_2023_1_9)
#
# Hyperlinks <- rbind(hyperlinks_2023_1_9) # The variable Hyperlinks will aggregate all the hyperlinks for all rounds
# names(Hyperlinks)[1] <- "hyperlink" # make sure that column heading is the same
# Totallinks <- nrow(Hyperlinks) # count the number of total applications

# %% [markdown]
# ## **Get a list of awarded projects**
#
# [First round awards](https://https://www.treasurer.ca.gov/ctcac/2023/approved-recommendations.pdf) shows a pdf file of the 9% awarded members. Using Power Query, I scraped the award information in excel and removed all the columns except the project number. The code below brings that information in a variable called **AwardedProjects_9**
#
# Note that this part may have to be done separately. The excel file should only include one column being the project number.

# %% [markdown]
# ## **Load all the helper Functions**
#
# Basically, if a step is repeated at any point, I made that into a function. There is one file that consolidates everything

# %%
# %%R
#
# source("/content/drive/MyDrive/LIHTC Scraping/Code/HelperFunctions/HelperFunctionLoad")
#
# head(Hyperlinks)
# Out:
#                                                                        hyperlink
# 1 https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/CA-23-001.xlsx
# 2 https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/CA-23-002.xlsx
# 3 https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/CA-23-003.xlsx
# 4 https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/CA-23-004.xlsx
# 5 https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/CA-23-005.xlsx
# 6 https://www.treasurer.ca.gov/ctcac/2023/firstround/applications/CA-23-006.xlsx

# %% [markdown]
# ## **Scrape Application Worksheet**

# %%
# %%R
